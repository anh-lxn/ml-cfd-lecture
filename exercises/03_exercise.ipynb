# %% [markdown]
# # Questions asked

# %% [markdown]
# - How many cells does the mesh consist of? -> 200 Cells

# %% [markdown]
# ```
# source $ML_CFD_BASE/RunFunctions
# runApplication checkMesh
# cat log.checkMesh
# ```
# Mesh stats
#     points:           804
#     internal points:  0
#     faces:            1001
#     internal faces:   199
#     **cells:            200**
#     faces per cell:   6
#     boundary patches: 6
#     point zones:      0
#     face zones:       0
#     cell zones:       0

# %% [markdown]
# - What are the boundary conditions for $U$?

# %% [markdown]
# U = (0,0,0) at the bottom
# 2D, because front and back are empty

# %% [markdown]
# - What is the driving force for this flow? Tip: check the dictionary *system/fvOptions* and consult the [documentation](https://www.openfoam.com/documentation/guides/v2112/doc/index.html).
